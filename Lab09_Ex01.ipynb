// %% [markdown]
// # Lab 9 Exercise 1
//
// ## การใช้งาน Modifier

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotbet new conxole --name Lab09_Ex01
// ```

// %% [markdown]
// ถ้ารันคำสั่งไม่ได้ ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Person.name = "_________________";
// >   System.conso1e.writ1ine(Person.GetName());
// >
// >   static class Person
// >   {
// >       public static st__ng? name;
// >       public static stri__ GetName()
// >       {
// >           return $"Hello from {name}";
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotdet build  Lab09_Ex0_
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// PS C:\Users\user\Downloads\Lab\Lab09-CSharp-Class-Part-II> dotnet build  Lab09_Ex01
// Restore complete (0.3s)
//   Lab09_Ex01 succeeded (2.7s) → Lab09_Ex01\bin\Debug\net9.0\Lab09_Ex01.dll
//
// Build succeeded in 3.5s

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotxet run --project Lab_9_Ex_1
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// Hello from sunisa

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// โค้ดเเสดงผลข้อความ Hello from sunisa ในConsole.

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Static field และ static method ต่างจาก instance field และ instance method อย่างไร

// %% [markdown]
// ตอบ Static Field / Static Method → ใช้กับคลาสโดยตรง, แชร์ค่าให้ทุกออบเจ็กต์
//
// Instance Field / Instance Method → ใช้กับออบเจ็กต์แต่ละตัว, มีค่าของตัวเอง

// %% [markdown]
// 2. เหตุใดเราจึงสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อ class โดยไม่ต้องสร้าง object

// %% [markdown]
// ตอบ เพราะ ทั้งสองเป็น static field และ static method` ซึ่งเป็นสมาชิกของคลาส ไม่ใช่ของออบเจ็กต์

// %% [markdown]
// 3. Static class มีข้อจำกัดอะไรบ้าง

// %% [markdown]
// ตอบ สร้างออบเจ็กต์ไม่ได้ → ห้ามใช้ new
//
// ไม่มี instance field/method → ทุกอย่างต้องเป็น static
//
// สืบทอด (inheritance) ไม่ได้ → ห้ามเป็นคลาสแม่หรือคลาสลูก
//
// ใช้ Interface ไม่ได้ → Implement interface ไม่ได้
//
// ใช้เป็น Generic Class ไม่ได้ → แต่ใช้ Generic Method ได้

// %% [markdown]
// 4. เราไม่สามารถสร้าง instance ของ static class ได้เพราะอะไร

// %% [markdown]
// ตอบ เรา ไม่สามารถสร้าง instance ของ static class ได้ เพราะ ไม่มี Constructor → ไม่สามารถใช้ new ได้
// ถูกโหลดเข้าหน่วยความจำเพียงครั้งเดียว → ไม่ต้องสร้างออบเจ็กต์
//
// C# บังคับไม่ให้สร้างออบเจ็กต์ → คอมไพเลอร์ป้องกันการใช้ new
//
// static class ใช้สำหรับเมธอดระดับคลาส เช่น Utility Functions (Math.Abs(), Console.WriteLine())

// %% [markdown]
// 5. ประโยชน์ของการใช้ static class คืออะไร  มีสถานการณ์ใดบ้างที่เราควรใช้ static class

// %% [markdown]
// ตอบ ประหยัดหน่วยความจำ → โหลดเพียงครั้งเดียวและใช้ร่วมกันทั้งโปรแกรม
//
// ไม่ต้องสร้างออบเจ็กต์ → ใช้งานง่าย แค่เรียกผ่านชื่อคลาส
//
// ป้องกันการเปลี่ยนแปลงค่าโดยไม่จำเป็น → ไม่มี instance จึงลดความซับซ้อน
//
// เพิ่มความเร็ว → เรียกใช้งานได้ทันที โดยไม่ต้องสร้างและจัดการออบเจ็กต์
