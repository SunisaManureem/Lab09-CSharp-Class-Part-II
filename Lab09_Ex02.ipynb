// %% [markdown]
// # Lab 9 Exercise 2
//
// ## การใช้งาน Modifier

// %% [markdown]
// 1. สร้าง console application project
//
// ```
//     dothet new conwole __name Lab09_Ex02
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// >  ```csharp
// >       Person.name = "___________________";
// >       System.Cons01e.WrifeLine(Person.GetName());
// >
// >       static Class Person
// >       {
// >           stαtic pub1ic  string? name;
// >           stαtic pub1ic  string GetName()
// >           {
// >               return $"Hello from {nxme}";
// >           }
// >       }
// >  ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
//     dotpet build  Lab09_Ex52
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// Restore complete (0.3s)
//   Lab09_Ex02 succeeded (2.6s) → Lab09_Ex02\bin\Debug\net9.0\Lab09_Ex02.dll
//
// Build succeeded in 3.3s

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd
//     dotaet run --profect Lab19_Ex02
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// Hello from sunisa

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// โค้ดเเสดงผลข้อความ Hello from sunisa ในConsole.

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. เมื่อกำหนดให้สมาชิกในคลาสให้มี Access Modifier ดังต่อไปนี้ จะสามารถเข้าถึงจากที่ไหนได้บ้าง

// %% [markdown]
// 1.1 public

// %% [markdown]
// สามารถเข้าถึงได้จากทุกที่

// %% [markdown]
// 1.2 private

// %% [markdown]
//  เข้าถึงได้เฉพาะภายในคลาสเท่านั้น

// %% [markdown]
// 1.3 protected

// %% [markdown]
// เข้าถึงได้ภายในคลาสและคลาสที่สืบทอด (subclass)

// %% [markdown]
// 1.4 internal

// %% [markdown]
//  เข้าถึงได้เฉพาะภายใน assembly เดียวกัน (สำหรับภาษา C#) หรือในโปรเจกต์เดียวกันเท่านั้น ไม่สามารถเข้าถึงจากภายนอก assembly ได้.

// %% [markdown]
// 1.5 protected internal

// %% [markdown]
// สามารถเข้าถึงได้จากทั้งใน package เดียวกันและคลาสที่สืบทอดจากคลาสนั้น ๆ แม้จะอยู่ใน assembly ต่างกันก็ได้.
